# %%
import tensorflow_datasets as tfds

# %%
data = tfds.load(
    'waymo_open_dataset/v1.0',
    data_dir='gs://waymo_open_dataset_v_1_0_0_individual_files/tensorflow_datasets'
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/utils/py_utils.py:415, in try_reraise(*args, **kwargs)
#     414 try:
# --> 415   yield
#     416 except Exception as e:  # pylint: disable=broad-except
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/load.py:212, in builder(name, try_gcs, **builder_kwargs)
#     211   with py_utils.try_reraise(prefix=f'Failed to construct dataset {name}: '):
# --> 212     return cls(**builder_kwargs)  # pytype: disable=not-instantiable
#     214 # If neither the code nor the files are found, raise DatasetNotFoundError
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/logging/__init__.py:288, in builder_init.<locals>.decorator(function, dsbuilder, args, kwargs)
#     287 try:
# --> 288   return function(*args, **kwargs)
#     289 except Exception:
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/dataset_builder.py:1270, in FileReaderBuilder.__init__(self, file_format, **kwargs)
#    1260 """Initializes an instance of FileReaderBuilder.
#    1261
#    1262 Callers must pass arguments as keyword arguments.
#    (...)
#    1268   **kwargs: Arguments passed to `DatasetBuilder`.
#    1269 """
# -> 1270 super().__init__(**kwargs)
#    1271 self.info.set_file_format(file_format)
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/logging/__init__.py:288, in builder_init.<locals>.decorator(function, dsbuilder, args, kwargs)
#     287 try:
# --> 288   return function(*args, **kwargs)
#     289 except Exception:
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/dataset_builder.py:271, in DatasetBuilder.__init__(self, data_dir, config, version)
#     270 # Compute the base directory (for download) and dataset/version directory.
# --> 271 self._data_dir_root, self._data_dir = self._build_data_dir(data_dir)
#     272 if self.data_path.exists():
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/dataset_builder.py:978, in DatasetBuilder._build_data_dir(self, given_data_dir)
#     977 full_builder_dir = os.path.join(data_dir_root, builder_dir)
# --> 978 data_dir_versions = set(utils.version.list_all_versions(full_builder_dir))
#     979 # Check for existence of the requested version
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/utils/version.py:193, in list_all_versions(root_dir)
#     192 root_dir = epath.Path(root_dir)
# --> 193 if not root_dir.exists():
#     194   return []
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/etils/epath/gpath.py:131, in _GPath.exists(self)
#     130 """Returns True if self exists."""
# --> 131 return self._backend.exists(self._path_str)
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/etils/epath/backend.py:215, in _TfBackend.exists(self, path)
#     214 def exists(self, path: PathLike) -> bool:
# --> 215   return self.gfile.exists(path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/etils/epath/backend.py:205, in _TfBackend.gfile(self)
#     203 @property
#     204 def gfile(self):
# --> 205   return self.tf.io.gfile
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/etils/epath/backend.py:198, in _TfBackend.tf(self)
#     197 except ImportError as e:
# --> 198   raise ImportError(
#     199       f'{e}. To use epath.Path with gs://, TensorFlow should be installed.'
#     200   ) from None
#     201 return tensorflow
#
# ImportError: No module named 'tensorflow'. To use epath.Path with gs://, TensorFlow should be installed.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = tfds.load(
#       2     'waymo_open_dataset/v1.0',
#       3     data_dir='gs://waymo_open_dataset_v_1_0_0_individual_files/tensorflow_datasets'
#       4 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/logging/__init__.py:169, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     167 metadata = self._start_call()
#     168 try:
# --> 169   return function(*args, **kwargs)
#     170 except Exception:
#     171   metadata.mark_error()
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/load.py:634, in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     502 @tfds_logging.load()
#     503 def load(
#     504     name: str,
#    (...)
#     519 ):
#     520   # pylint: disable=line-too-long
#     521   """Loads the named dataset into a `tf.data.Dataset`.
#     522
#     523   `tfds.load` is a convenience method that:
#    (...)
#     632       Split-specific information is available in `ds_info.splits`.
#     633   """
# --> 634   dbuilder = _fetch_builder(
#     635       name,
#     636       data_dir,
#     637       builder_kwargs,
#     638       try_gcs,
#     639   )
#     640   _download_and_prepare_builder(dbuilder, download, download_and_prepare_kwargs)
#     642   if as_dataset_kwargs is None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/load.py:489, in _fetch_builder(name, data_dir, builder_kwargs, try_gcs)
#     486 if builder_kwargs is None:
#     487   builder_kwargs = {}
# --> 489 return builder(name, data_dir=data_dir, try_gcs=try_gcs, **builder_kwargs)
#
# File ~/.pyenv/versions/3.9.16/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/logging/__init__.py:169, in _FunctionDecorator.__call__(self, function, instance, args, kwargs)
#     167 metadata = self._start_call()
#     168 try:
# --> 169   return function(*args, **kwargs)
#     170 except Exception:
#     171   metadata.mark_error()
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/load.py:212, in builder(name, try_gcs, **builder_kwargs)
#     210 if cls:
#     211   with py_utils.try_reraise(prefix=f'Failed to construct dataset {name}: '):
# --> 212     return cls(**builder_kwargs)  # pytype: disable=not-instantiable
#     214 # If neither the code nor the files are found, raise DatasetNotFoundError
#     215 raise not_found_error
#
# File ~/.pyenv/versions/3.9.16/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/utils/py_utils.py:417, in try_reraise(*args, **kwargs)
#     415   yield
#     416 except Exception as e:  # pylint: disable=broad-except
# --> 417   reraise(e, *args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/waymo-open-Xzb6IqkH-py3.9/lib/python3.9/site-packages/tensorflow_datasets/core/utils/py_utils.py:384, in reraise(e, prefix, suffix)
#     382   else:
#     383     exception = RuntimeError(f'{type(e).__name__}: {msg}')
# --> 384   raise exception from e
#     385 # Otherwise, modify the exception in-place
#     386 elif len(e.args) <= 1:
#
# ImportError: Failed to construct dataset waymo_open_dataset: No module named 'tensorflow'. To use epath.Path with gs://, TensorFlow should be installed.
